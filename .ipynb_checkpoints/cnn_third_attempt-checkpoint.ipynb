# %%
# !pip install keras cython h5py --quiet

# %%
import pandas as pd
import numpy as np

# %%
import keras
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
import zipfile

# %%
four_keypoints_3 = pd.read_pickle('four_keypoints_3.data')

# %%
X = four_keypoints_3['Image'].apply(lambda image: np.fromstring(image, sep=' '))
y = four_keypoints_3.drop('Image', axis=1).values

# %%
X.shape
# Out:
# (4600,)

# %%
X = np.vstack(X) / 255
y = (y - 48) / 48

# %%
from keras.layers import Input, Conv2D, MaxPool2D, Dropout, Activation, Dense, Flatten
from keras.models import Sequential

# %%
# mlp = Sequential([
#     Dense(100, input_dim=9216),
#     Activation('relu'),
#     Dense(8)
# ])

# %%
# mlp.summary()

# %%
# mlp.compile(optimizer='sgd',
#            loss='mse',
#            metrics=None)

# %%
# mlp.fit(X, y, epochs=100, validation_split=.2)

# %%
# mlp.evaluate(X, y)

# %%
cnn = Sequential([
    Conv2D(32, kernel_size=(3, 3),
           activation='relu',
           input_shape=(96,96,1)),
    MaxPool2D(pool_size=(2, 2)),
    Dropout(.2),
    
    Conv2D(64, kernel_size=(2, 2),
           activation='relu'),
    MaxPool2D(pool_size=(2, 2)),
    Dropout(.3),  
    
    Flatten(),
    Dense(1000, activation='relu'),

    Dense(8)
])

# %%
cnn.compile(loss='mse', optimizer='sgd')

# %%
X2 = X.reshape(-1, 96, 96, 1)

# %%
cnn.fit(X2, y, validation_split=.2, epochs=200)
# Out:
# Train on 3680 samples, validate on 920 samples
# Epoch 1/200
# 3680/3680 [==============================] - 5s - loss: 0.0136 - val_loss: 0.0175
# Epoch 2/200
# 3680/3680 [==============================] - 5s - loss: 0.0109 - val_loss: 0.0165
# Epoch 3/200
# 3680/3680 [==============================] - 5s - loss: 0.0106 - val_loss: 0.0164
# Epoch 4/200
# 3680/3680 [==============================] - 5s - loss: 0.0104 - val_loss: 0.0163
# Epoch 5/200
# 3680/3680 [==============================] - 5s - loss: 0.0105 - val_loss: 0.0162
# Epoch 6/200
# 3680/3680 [==============================] - 5s - loss: 0.0104 - val_loss: 0.0162
# Epoch 7/200
# 3680/3680 [==============================] - 5s - loss: 0.0104 - val_loss: 0.0161
# Epoch 8/200
# 3680/3680 [==============================] - 5s - loss: 0.0102 - val_loss: 0.0163
# Epoch 9/200
# 3680/3680 [==============================] - 5s - loss: 0.0102 - val_loss: 0.0161
# Epoch 10/200
# 3680/3680 [==============================] - 5s - loss: 0.0103 - val_loss: 0.0160
# Epoch 11/200
# 3680/3680 [==============================] - 5s - loss: 0.0101 - val_loss: 0.0160
# Epoch 12/200
# 3680/3680 [==============================] - 5s - loss: 0.0103 - val_loss: 0.0158
# Epoch 13/200
# 3680/3680 [==============================] - 5s - loss: 0.0101 - val_loss: 0.0158
# Epoch 14/200
# 3680/3680 [==============================] - 5s - loss: 0.0100 - val_loss: 0.0160
# Epoch 15/200
# 3680/3680 [==============================] - 5s - loss: 0.0101 - val_loss: 0.0159
# Epoch 16/200
# 3680/3680 [==============================] - 5s - loss: 0.0101 - val_loss: 0.0160
# Epoch 17/200
# 3680/3680 [==============================] - 5s - loss: 0.0099 - val_loss: 0.0158
# Epoch 114/200
# 3680/3680 [==============================] - 5s - loss: 0.0077 - val_loss: 0.0139
# Epoch 115/200
# 3680/3680 [==============================] - 5s - loss: 0.0076 - val_loss: 0.0138
# Epoch 116/200
# 3680/3680 [==============================] - 5s - loss: 0.0077 - val_loss: 0.0138
# Epoch 117/200
# 3680/3680 [==============================] - 5s - loss: 0.0076 - val_loss: 0.0137
# Epoch 118/200
# 3680/3680 [==============================] - 5s - loss: 0.0077 - val_loss: 0.0136
# Epoch 119/200
# 3680/3680 [==============================] - 5s - loss: 0.0076 - val_loss: 0.0138
# Epoch 120/200
# 3680/3680 [==============================] - 5s - loss: 0.0077 - val_loss: 0.0138
# Epoch 121/200
# 3680/3680 [==============================] - 5s - loss: 0.0074 - val_loss: 0.0137
# Epoch 122/200
# 3680/3680 [==============================] - 5s - loss: 0.0076 - val_loss: 0.0138
# Epoch 123/200
# 3680/3680 [==============================] - 5s - loss: 0.0075 - val_loss: 0.0138
# Epoch 124/200
# 3680/3680 [==============================] - 5s - loss: 0.0075 - val_loss: 0.0136
# Epoch 125/200
# 3680/3680 [==============================] - 5s - loss: 0.0074 - val_loss: 0.0138
# Epoch 126/200
# 3680/3680 [==============================] - 5s - loss: 0.0074 - val_loss: 0.0136
# Epoch 127/200
# 3680/3680 [==============================] - 5s - loss: 0.0074 - val_loss: 0.0136
# Epoch 128/200
# 3680/3680 [==============================] - 5s - loss: 0.0075 - val_loss: 0.0136
# Epoch 129/200
# 3680/3680 [==============================] - 5s - loss: 0.0074 - val_loss: 0.0137
# Epoch 130/200
# 3680/3680 [==============================] - 5s - loss: 0.0075 - val_loss: 0.0135
# Epoch 131/200
# 3680/3680 [==============================] - 5s - loss: 0.0074 - val_loss: 0.0136
# Epoch 132/200
# 3680/3680 [==============================] - 5s - loss: 0.0074 - val_loss: 0.0136
# Epoch 133/200
# 3680/3680 [==============================] - 5s - loss: 0.0074 - val_loss: 0.0135
# Epoch 134/200
# 3680/3680 [==============================] - 5s - loss: 0.0074 - val_loss: 0.0135
# Epoch 135/200
# 3680/3680 [==============================] - 5s - loss: 0.0074 - val_loss: 0.0136
# Epoch 136/200
# 3680/3680 [==============================] - 5s - loss: 0.0073 - val_loss: 0.0134
# Epoch 137/200
# 3680/3680 [==============================] - 5s - loss: 0.0074 - val_loss: 0.0134
# Epoch 138/200
# 3680/3680 [==============================] - 5s - loss: 0.0073 - val_loss: 0.0135
# Epoch 139/200
# 3680/3680 [==============================] - 5s - loss: 0.0074 - val_loss: 0.0134
# Epoch 140/200
# 3680/3680 [==============================] - 5s - loss: 0.0073 - val_loss: 0.0135
# Epoch 141/200
# 3680/3680 [==============================] - 5s - loss: 0.0072 - val_loss: 0.0135
# Epoch 142/200
# 3680/3680 [==============================] - 5s - loss: 0.0072 - val_loss: 0.0134
# Epoch 143/200
# 3680/3680 [==============================] - 5s - loss: 0.0073 - val_loss: 0.0135
# Epoch 144/200
# 3680/3680 [==============================] - 5s - loss: 0.0072 - val_loss: 0.0134
# Epoch 145/200
# 3680/3680 [==============================] - 5s - loss: 0.0072 - val_loss: 0.0135
# Epoch 146/200
# 3680/3680 [==============================] - 5s - loss: 0.0073 - val_loss: 0.0134
# Epoch 147/200
# 3680/3680 [==============================] - 5s - loss: 0.0072 - val_loss: 0.0135
# Epoch 148/200
# 3680/3680 [==============================] - 5s - loss: 0.0072 - val_loss: 0.0135
# Epoch 149/200
# 3680/3680 [==============================] - 5s - loss: 0.0071 - val_loss: 0.0134
# Epoch 150/200
# 3680/3680 [==============================] - 5s - loss: 0.0071 - val_loss: 0.0133
# Epoch 151/200
# 3680/3680 [==============================] - 5s - loss: 0.0071 - val_loss: 0.0133
# Epoch 152/200
# 3680/3680 [==============================] - 5s - loss: 0.0071 - val_loss: 0.0134
# Epoch 153/200
# 3680/3680 [==============================] - 5s - loss: 0.0071 - val_loss: 0.0132
# Epoch 154/200
# 3680/3680 [==============================] - 5s - loss: 0.0070 - val_loss: 0.0131
# Epoch 155/200
# 3680/3680 [==============================] - 5s - loss: 0.0069 - val_loss: 0.0131
# Epoch 156/200
# 3680/3680 [==============================] - 5s - loss: 0.0070 - val_loss: 0.0132
# Epoch 157/200
# 3680/3680 [==============================] - 5s - loss: 0.0070 - val_loss: 0.0133
# Epoch 158/200
# 3680/3680 [==============================] - 5s - loss: 0.0071 - val_loss: 0.0133
# Epoch 159/200
# 3680/3680 [==============================] - 5s - loss: 0.0070 - val_loss: 0.0133
# Epoch 160/200
# 3680/3680 [==============================] - 5s - loss: 0.0069 - val_loss: 0.0131
# Epoch 161/200
# 3680/3680 [==============================] - 5s - loss: 0.0069 - val_loss: 0.0131
# Epoch 162/200
# 3680/3680 [==============================] - 5s - loss: 0.0069 - val_loss: 0.0131
# Epoch 163/200
# 3680/3680 [==============================] - 5s - loss: 0.0070 - val_loss: 0.0132
# Epoch 164/200
# 3680/3680 [==============================] - 5s - loss: 0.0069 - val_loss: 0.0132
# Epoch 165/200
# 3680/3680 [==============================] - 5s - loss: 0.0070 - val_loss: 0.0131
# Epoch 166/200
# 3680/3680 [==============================] - 5s - loss: 0.0069 - val_loss: 0.0130
# Epoch 167/200
# 3680/3680 [==============================] - 5s - loss: 0.0070 - val_loss: 0.0130
# Epoch 168/200
# 3680/3680 [==============================] - 5s - loss: 0.0069 - val_loss: 0.0131
# Epoch 169/200
# 3680/3680 [==============================] - 5s - loss: 0.0069 - val_loss: 0.0131
# Epoch 170/200
# 3680/3680 [==============================] - 5s - loss: 0.0068 - val_loss: 0.0131
# Epoch 171/200
# 3680/3680 [==============================] - 5s - loss: 0.0067 - val_loss: 0.0130
# Epoch 172/200
# 3680/3680 [==============================] - 5s - loss: 0.0068 - val_loss: 0.0130
# Epoch 173/200
# 3680/3680 [==============================] - 5s - loss: 0.0068 - val_loss: 0.0133
# Epoch 174/200
# 3680/3680 [==============================] - 5s - loss: 0.0068 - val_loss: 0.0130
# Epoch 175/200
# 3680/3680 [==============================] - 5s - loss: 0.0068 - val_loss: 0.0131
# Epoch 176/200
# 3680/3680 [==============================] - 5s - loss: 0.0067 - val_loss: 0.0131
# Epoch 177/200
# 3680/3680 [==============================] - 5s - loss: 0.0067 - val_loss: 0.0130
# Epoch 178/200
# 3680/3680 [==============================] - 5s - loss: 0.0068 - val_loss: 0.0130
# Epoch 179/200
# 3680/3680 [==============================] - 5s - loss: 0.0068 - val_loss: 0.0131
# Epoch 180/200
# 3680/3680 [==============================] - 5s - loss: 0.0067 - val_loss: 0.0129
# Epoch 181/200
# 3680/3680 [==============================] - 5s - loss: 0.0067 - val_loss: 0.0130
# Epoch 182/200
# 3680/3680 [==============================] - 5s - loss: 0.0067 - val_loss: 0.0130
# Epoch 183/200
# 3680/3680 [==============================] - 5s - loss: 0.0066 - val_loss: 0.0131
# Epoch 184/200
# 3680/3680 [==============================] - 5s - loss: 0.0066 - val_loss: 0.0128
# Epoch 185/200
# 3680/3680 [==============================] - 5s - loss: 0.0067 - val_loss: 0.0129
# Epoch 186/200
# 3680/3680 [==============================] - 5s - loss: 0.0067 - val_loss: 0.0128
# Epoch 187/200
# 3680/3680 [==============================] - 5s - loss: 0.0067 - val_loss: 0.0128
# Epoch 188/200
# 3680/3680 [==============================] - 5s - loss: 0.0066 - val_loss: 0.0129
# Epoch 189/200
# 3680/3680 [==============================] - 5s - loss: 0.0067 - val_loss: 0.0129
# Epoch 190/200
# 3680/3680 [==============================] - 5s - loss: 0.0066 - val_loss: 0.0129
# Epoch 191/200
# 3680/3680 [==============================] - 5s - loss: 0.0066 - val_loss: 0.0130
# Epoch 192/200
# 3680/3680 [==============================] - 5s - loss: 0.0066 - val_loss: 0.0129
# Epoch 193/200
# 3680/3680 [==============================] - 5s - loss: 0.0066 - val_loss: 0.0128
# Epoch 194/200
# 3680/3680 [==============================] - 5s - loss: 0.0065 - val_loss: 0.0128
# Epoch 195/200
# 3680/3680 [==============================] - 5s - loss: 0.0065 - val_loss: 0.0127
# Epoch 196/200
# 3680/3680 [==============================] - 5s - loss: 0.0066 - val_loss: 0.0127
# Epoch 197/200
# 3680/3680 [==============================] - 5s - loss: 0.0066 - val_loss: 0.0129
# Epoch 198/200
# 3680/3680 [==============================] - 5s - loss: 0.0066 - val_loss: 0.0128
# Epoch 199/200
# 3680/3680 [==============================] - 5s - loss: 0.0066 - val_loss: 0.0129
# Epoch 200/200
# 3680/3680 [==============================] - 5s - loss: 0.0066 - val_loss: 0.0128

# %%
# cnn.save('cnn1.h5')

# %%
with zipfile.ZipFile('data/test.zip') as zip:
    with zip.open('test.csv') as myZip:
        df_test = pd.read_csv(myZip)

# %%
X_test = df_test['Image'].apply(lambda image: np.fromstring(image, sep=' '))
X_test = np.vstack(X_test)/255

# %%
X2_test = X_test.reshape(-1, 96, 96, 1)

# %%
y_pred_cnn = cnn.predict(X2_test)

# %%
y_pred_cnn = y_pred_cnn*48 + 48

# %%
cnn_pred_df = pd.DataFrame(y_pred_cnn, columns=four_keypoints_3.drop('Image', axis=1).columns)

# %%
f, ax = plt.subplots(4, 4, figsize=(16, 16))
for i in range(4):
    for j in range(4):
        for k in range(4):
            ax[i, j].plot(cnn_pred_df.iloc[i*4 + j, 2*k], cnn_pred_df.iloc[i*4 + j, 2*k+1], c='r', marker='o')
        ax[i, j].imshow(X_test[i*4 + j].reshape(96, 96), cmap='gray')

# %%
a = four_keypoints_3[four_keypoints_3['nose_tip_y'] == max(four_keypoints_3['nose_tip_y'])]

# %%
b = np.fromstring(a.Image, sep=' ')
b = np.vstack(b)/255

# %%
c = b.reshape(-1, 96, 96, 1)

# %%
single_pred = cnn.predict(c)*48 +48
single_pred = pd.DataFrame(single_pred, columns=four_keypoints_3.drop('Image', axis=1).columns)

# %%
for k in range(4):
    plt.plot(single_pred.iloc[0, 2*k], cnn_pred_df.iloc[0, 2*k+1], c='r', marker='o')
plt.imshow(b.reshape(96, 96), cmap='gray')

# %%
# from keras.models import load_model

# cnn1 = load_model('cnn1.h5')

# %%
y_train_pred_cnn = cnn.predict(X2)

# %%
y_train_pred_cnn = y_train_pred_cnn*48 + 48

# %%
cnn_train_pred_df = pd.DataFrame(y_train_pred_cnn, columns=four_keypoints_3.drop('Image', axis=1).columns)

# %%
from random import randint

# %%
rndm = randint(0, 4000)
f, ax = plt.subplots(4, 4, figsize=(16, 16))
for i in range(4):
    for j in range(4):
        for k in range(4):
            ax[i, j].plot(cnn_train_pred_df.iloc[i*4 + j + rndm, 2*k], cnn_train_pred_df.iloc[i*4 + j + rndm, 2*k+1], c='r', marker='o')
        ax[i, j].imshow(X[i*4 + j + rndm].reshape(96, 96), cmap='gray')

# %%
with zipfile.ZipFile('data/training.zip') as zip:
    with zip.open('training.csv') as myZip:
        df = pd.read_csv(myZip)

# %%
df = df.loc[:, ['nose_tip_x', 'nose_tip_y',
                'mouth_center_bottom_lip_x', 'mouth_center_bottom_lip_y',
                'left_eye_center_x', 'left_eye_center_y',
                'right_eye_center_x', 'right_eye_center_y',
                'Image']
           ].dropna()

df.shape
# Out:
# (7000, 9)

# %%
X = df['Image'].apply(lambda image: np.fromstring(image, sep=' '))
y = df.drop('Image', axis=1).values

# %%
X = np.vstack(X) / 255
y = (y - 48) / 48

# %%
X2 = X.reshape(-1, 96, 96, 1)

# %%
cnn.evaluate(X2, y)
# Out:
# 6976/7000 [============================>.] - ETA: 0s
# 0.010399803729993957

# %%
original_df_preds = cnn.predict(X2)

# %%
original_df_preds = original_df_preds*48 + 48

# %%
original_df_preds = pd.DataFrame(original_df_preds, columns=four_keypoints_3.drop('Image', axis=1).columns)

# %%
rndm = randint(0, 6980)
f, ax = plt.subplots(4, 4, figsize=(16, 16))
for i in range(4):
    for j in range(4):
        for k in range(4):
            ax[i, j].plot(original_df_preds.iloc[i*4 + j + rndm, 2*k], original_df_preds.iloc[i*4 + j + rndm, 2*k+1], c='r', marker='o')
        ax[i, j].imshow(X[i*4 + j + rndm].reshape(96, 96), cmap='gray')
